# %%
'''
mongodb+srv://prakhars210:Abhashukla@27@cluster0.g6kmzuo.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0
'''

# %%
import pandas as pd
df= pd.read_csv("AEP_hourly.csv")
print(df.head())
# Out:
#               Datetime   AEP_MW
# 0  2004-12-31 01:00:00  13478.0
# 1  2004-12-31 02:00:00  12865.0
# 2  2004-12-31 03:00:00  12577.0
# 3  2004-12-31 04:00:00  12517.0
# 4  2004-12-31 05:00:00  12670.0

# %%
print(df.shape)
# Out:
# (121273, 2)

# %%
data=df.to_dict(orient='records')
data
# Out:
# [{'Datetime': '2004-12-31 01:00:00', 'AEP_MW': 13478.0},
#  {'Datetime': '2004-12-31 02:00:00', 'AEP_MW': 12865.0},
#  {'Datetime': '2004-12-31 03:00:00', 'AEP_MW': 12577.0},
#  {'Datetime': '2004-12-31 04:00:00', 'AEP_MW': 12517.0},
#  {'Datetime': '2004-12-31 05:00:00', 'AEP_MW': 12670.0},
#  {'Datetime': '2004-12-31 06:00:00', 'AEP_MW': 13038.0},
#  {'Datetime': '2004-12-31 07:00:00', 'AEP_MW': 13692.0},
#  {'Datetime': '2004-12-31 08:00:00', 'AEP_MW': 14297.0},
#  {'Datetime': '2004-12-31 09:00:00', 'AEP_MW': 14719.0},
#  {'Datetime': '2004-12-31 10:00:00', 'AEP_MW': 14941.0},
#  {'Datetime': '2004-12-31 11:00:00', 'AEP_MW': 15184.0},
#  {'Datetime': '2004-12-31 12:00:00', 'AEP_MW': 15009.0},
#  {'Datetime': '2004-12-31 13:00:00', 'AEP_MW': 14808.0},
#  {'Datetime': '2004-12-31 14:00:00', 'AEP_MW': 14522.0},
#  {'Datetime': '2004-12-31 15:00:00', 'AEP_MW': 14349.0},
#  {'Datetime': '2004-12-31 16:00:00', 'AEP_MW': 14107.0},
# ...

# %%
DB_NAME = "AEP"
COLLECTION_NAME = "AEP_hourly"
CONNECTION_STRING = "mongodb+srv://prakhars210:Abhashukla27@cluster0.g6kmzuo.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo
client=pymongo.MongoClient(CONNECTION_STRING)
data_base=client[DB_NAME]
collection=data_base[COLLECTION_NAME]
rec=collection.insert_many(data)

# %%
records=collection.find()
for i,j in enumerate(records):
    print(f"{i} : {j}")
    if i==10:
        break
# Out:
# 0 : {'_id': ObjectId('680b42a912778ea95fad3bcb'), 'Datetime': '2004-12-31 01:00:00', 'AEP_MW': 13478.0}
# 1 : {'_id': ObjectId('680b42a912778ea95fad3bcc'), 'Datetime': '2004-12-31 02:00:00', 'AEP_MW': 12865.0}
# 2 : {'_id': ObjectId('680b42a912778ea95fad3bcd'), 'Datetime': '2004-12-31 03:00:00', 'AEP_MW': 12577.0}
# 3 : {'_id': ObjectId('680b42a912778ea95fad3bce'), 'Datetime': '2004-12-31 04:00:00', 'AEP_MW': 12517.0}
# 4 : {'_id': ObjectId('680b42a912778ea95fad3bcf'), 'Datetime': '2004-12-31 05:00:00', 'AEP_MW': 12670.0}
# 5 : {'_id': ObjectId('680b42a912778ea95fad3bd0'), 'Datetime': '2004-12-31 06:00:00', 'AEP_MW': 13038.0}
# 6 : {'_id': ObjectId('680b42a912778ea95fad3bd1'), 'Datetime': '2004-12-31 07:00:00', 'AEP_MW': 13692.0}
# 7 : {'_id': ObjectId('680b42a912778ea95fad3bd2'), 'Datetime': '2004-12-31 08:00:00', 'AEP_MW': 14297.0}
# 8 : {'_id': ObjectId('680b42a912778ea95fad3bd3'), 'Datetime': '2004-12-31 09:00:00', 'AEP_MW': 14719.0}
# ...

# %%
    df= pd.DataFrame(list(collection.find({},{"_id":0})))
    df.head()
# Out:
#               Datetime   AEP_MW
# 0  2004-12-31 01:00:00  13478.0
# 1  2004-12-31 02:00:00  12865.0
# 2  2004-12-31 03:00:00  12577.0
# 3  2004-12-31 04:00:00  12517.0
# 4  2004-12-31 05:00:00  12670.0
